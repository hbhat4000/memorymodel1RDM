# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
coeffs = np.loadtxt('./deltaresults/fci_h2_6-31gss_0.050000_6000_coeffs.txt',
                    delimiter=',',dtype=np.complex128)

# %%
for j in range(100):
    plt.figure(figsize=(3,2))
    plt.plot(coeffs[:1000,j].real,coeffs[:1000,j].imag)
    plt.show()
